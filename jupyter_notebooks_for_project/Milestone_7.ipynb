# %%
import pandas as pd

df = pd.read_csv('/Users/apple/Documents/GitHub/Data_Science_Airbnb/airbnb_datasets/clean_tabular_data.csv')

# %%
df
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4    cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..                                    ...         ...
# 825  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 826  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 827  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 828  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 829  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
df.iloc[498]
# Out:
# ID                                   4c917b3c-d693-4ee4-a321-f5babc728dc9
# Category                                                    Amazing pools
# Title                                       Stunning Cotswolds Water Park
# Description                                            sleeps 6 with pool
# Amenities               ['About this space', 'Enjoy a discount for boo...
# Location                ['What this place offers', 'Bathroom', 'Hair d...
# guests                            Somerford Keynes England United Kingdom
# beds                                                                  6.0
# bathrooms                                                             4.0
# Price_Night                                                             3
# Cleanliness_rating                                                  200.0
# Accuracy_rating                                                       4.8
# Communication_rating                                                  4.9
# ...

# %%
df['guests'] = df['guests'] = pd.to_numeric(df['guests'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/Data_Science_Airbnb/airbnb_venv/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2363, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Somerford Keynes England United Kingdom"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df['guests'] = df['guests'] = pd.to_numeric(df['guests'])
#
# File ~/Documents/GitHub/Data_Science_Airbnb/airbnb_venv/lib/python3.9/site-packages/pandas/core/tools/numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    830 non-null    object
#  1   Category              830 non-null    object
#  2   Title                 830 non-null    object
#  3   Description           830 non-null    object
#  4   Amenities             830 non-null    object
#  5   Location              830 non-null    object
#  6   guests                830 non-null    object
#  7   beds                  830 non-null    float64
#  8   bathrooms             830 non-null    float64
#  9   Price_Night           830 non-null    int64
#  10  Cleanliness_rating    830 non-null    float64
#  11  Accuracy_rating       830 non-null    float64
#  12  Communication_rating  830 non-null    float64
#  13  Location_rating       830 non-null    float64
#  14  Check-in_rating       830 non-null    float64
# ...

# %%
df['bedrooms'] = pd.to_numeric(df['bedrooms'], errors='coerce')

# %%
df['bedrooms']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      2.0
#       ...
# 825    2.0
# 826    1.0
# 827    2.0
# 828    2.0
# 829    2.0
# Name: bedrooms, Length: 830, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    830 non-null    object
#  1   Category              830 non-null    object
#  2   Title                 830 non-null    object
#  3   Description           830 non-null    object
#  4   Amenities             830 non-null    object
#  5   Location              830 non-null    object
#  6   guests                830 non-null    object
#  7   beds                  830 non-null    float64
#  8   bathrooms             830 non-null    float64
#  9   Price_Night           830 non-null    int64
#  10  Cleanliness_rating    830 non-null    float64
#  11  Accuracy_rating       830 non-null    float64
#  12  Communication_rating  830 non-null    float64
#  13  Location_rating       830 non-null    float64
#  14  Check-in_rating       830 non-null    float64
# ...

# %%
df['bedrooms'] = pd.to_numeric(df['bedrooms'], errors='ignore')

# %%
df['bedrooms']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      2.0
#       ...
# 825    2.0
# 826    1.0
# 827    2.0
# 828    2.0
# 829    2.0
# Name: bedrooms, Length: 830, dtype: float64

# %%
df['guests'] = pd.to_numeric(df['guests'], errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    830 non-null    object
#  1   Category              830 non-null    object
#  2   Title                 830 non-null    object
#  3   Description           830 non-null    object
#  4   Amenities             830 non-null    object
#  5   Location              830 non-null    object
#  6   guests                830 non-null    object
#  7   beds                  830 non-null    float64
#  8   bathrooms             830 non-null    float64
#  9   Price_Night           830 non-null    int64
#  10  Cleanliness_rating    830 non-null    float64
#  11  Accuracy_rating       830 non-null    float64
#  12  Communication_rating  830 non-null    float64
#  13  Location_rating       830 non-null    float64
#  14  Check-in_rating       830 non-null    float64
# ...

# %%
airbnb_df = pd.read_csv('/Users/apple/Documents/GitHub/Data_Science_Airbnb/airbnb_datasets/clean_tabular_data.csv')
categories = airbnb_df['Category'].astype('category')
# print(categories)
encoder = pd.get_dummies(categories)
encoder = encoder.astype('int64')
airbnb_df = pd.concat([airbnb_df, encoder], axis=1)

# print(airbnb_df)
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    830 non-null    object
#  1   Category              830 non-null    object
#  2   Title                 830 non-null    object
#  3   Description           830 non-null    object
#  4   Amenities             830 non-null    object
#  5   Location              830 non-null    object
#  6   guests                830 non-null    object
#  7   beds                  830 non-null    float64
#  8   bathrooms             830 non-null    float64
#  9   Price_Night           830 non-null    int64
#  10  Cleanliness_rating    830 non-null    float64
#  11  Accuracy_rating       830 non-null    float64
#  12  Communication_rating  830 non-null    float64
#  13  Location_rating       830 non-null    float64
#  14  Check-in_rating       830 non-null    float64
# ...

# %% [markdown]
# ## After refactoring tabular_data.py

# %%
airbnb_df = pd.read_csv('/Users/apple/Documents/GitHub/Data_Science_Airbnb/airbnb_datasets/clean_tabular_data.csv')
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    829 non-null    object
#  1   Category              829 non-null    object
#  2   Title                 829 non-null    object
#  3   Description           829 non-null    object
#  4   Amenities             829 non-null    object
#  5   Location              829 non-null    object
#  6   guests                829 non-null    int64
#  7   beds                  829 non-null    float64
#  8   bathrooms             829 non-null    float64
#  9   Price_Night           829 non-null    int64
#  10  Cleanliness_rating    829 non-null    float64
#  11  Accuracy_rating       829 non-null    float64
#  12  Communication_rating  829 non-null    float64
#  13  Location_rating       829 non-null    float64
#  14  Check-in_rating       829 non-null    float64
# ...
